# %%
import pandas as pd

# %%
pd.read_csv("mindfulness.csv")
# Out:
#      mind1  mind2  mind3  mind4  mind5  stress1  stress2  stress3  stress4  \
# 0        4      3      4      4      5        4        8        7        9
# 1        8      7      7      7      6        4        5        3        2
# 2        5      7      5      4      4        5        4        6        4
# 3        3      2      4      5      3        6        4        6        8
# 4        1      7      6      5      6        5        4        6        5
# ..     ...    ...    ...    ...    ...      ...      ...      ...      ...
# 382      5      7      7      4      9        4        3        4        3
# 383      5      5      6      4      5        6        5        7        6
# 384      9     10      9      9      9        5       10        4        5
# 385      3      5      6      6      5        6        5        5        4
# 386      8      9      8      9      7        5        6        2        4
#
# ...
