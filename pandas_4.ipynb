# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly as px

# %%
df = pd.read_excel("titanic_save.xlsx")
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Continuous to categorical data conversion

# %%
pd.cut(df.age, bins = [0, 18, 25, 99], labels=['child', 'young_adult','adult']).head()
# Out:
# 0    young_adult
# 1          adult
# 2          adult
# 3          adult
# 4          adult
# Name: age, dtype: category
# Categories (3, object): ['child' < 'young_adult' < 'adult']

# %%
df['age_2'] = pd.cut(df.age, bins = [0, 18, 25, 99], labels=['child', 'young_adult','adult'])
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
df.age_2.unique()
# Out:
# ['young_adult', 'adult', NaN, 'child']
# Categories (3, object): ['child' < 'young_adult' < 'adult']

# %% [markdown]
# ### converting one set of values into anotherone

# %%
# df.sex.map({'male':0,'female':1})
df['sex_2'] = df.sex.map({'male':0,'female':1})
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
df['embark_2'] = df.embark_town.factorize()[0]
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone        age_2  \
# 0  Third    man        True  NaN  Southampton    no  False  young_adult
# 1  First  woman       False    C    Cherbourg   yes  False        adult
# 2  Third  woman       False  NaN  Southampton   yes   True        adult
# 3  First  woman       False    C  Southampton   yes  False        adult
# 4  Third    man        True  NaN  Southampton    no   True        adult
#
#    sex_2  embark_2
# 0      0         0
# 1      1         1
# ...

# %% [markdown]
# ### transpose a wide dataframe

# %%
# df.describe().shape
# df.describe().T

# %% [markdown]
# ### Reshaping data frame

# %%
df_2 = pd.read_excel("iris_dataset.xlsx")
df_2.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
staph_a = pd.DataFrame([['gen_1', 100, 200, 300], ['gen_2', 400, 500, 600],['gen_3', 700, 800, 900]],
                        columns=['gene_id','gen_length','gen_count', 'gc%'])

staph_a.head()
# Out:
#   gene_id  gen_length  gen_count  gc%
# 0   gen_1         100        200  300
# 1   gen_2         400        500  600
# 2   gen_3         700        800  900

# %%
staph_a.melt(id_vars='gene_id', var_name='proper', value_name='values')
# Out:
#   gene_id      proper  values
# 0   gen_1  gen_length     100
# 1   gen_2  gen_length     400
# 2   gen_3  gen_length     700
# 3   gen_1   gen_count     200
# 4   gen_2   gen_count     500
# 5   gen_3   gen_count     800
# 6   gen_1         gc%     300
# 7   gen_2         gc%     600
# 8   gen_3         gc%     900
